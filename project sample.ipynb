# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./social_media usage and emotional well-being.csv')

# %%
data.head()
# Out:
#    User_ID Age      Gender  Platform  Daily_Usage_Time (minutes)  \
# 0      500  27      Female  Snapchat                         120
# 1      488  21  Non-binary  Snapchat                          60
# 2      776  28  Non-binary  Snapchat                         115
# 3      869  27        Male  Telegram                         105
# 4      573  21  Non-binary  Facebook                          55
#
#    Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0              4                      40                         18
# 1              1                      18                          7
# 2              3                      38                         18
# 3              3                      48                         20
# 4              3                      17                          7
#
#    Messages_Sent_Per_Day Dominant_Emotion
# 0                     22          Neutral
# 1                     12          Neutral
# ...

# %%
data.tail()
# Out:
#      User_ID Age      Gender  Platform  Daily_Usage_Time (minutes)  \
# 98       184  22        Male   Twitter                          70
# 99       896  33        Male  LinkedIn                          85
# 100      708  24  Non-binary  Facebook                         110
# 101      993  24        Male  Telegram                          75
# 102       60  27        Male  Facebook                          60
#
#      Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 98               1                      20                          5
# 99               4                      35                         18
# 100              6                      35                         23
# 101              3                      37                         16
# 102              1                      10                          4
#
#      Messages_Sent_Per_Day Dominant_Emotion
# 98                      22          Neutral
# 99                      18          Boredom
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     103 non-null    int64
#  1   Age                         103 non-null    object
#  2   Gender                      103 non-null    object
#  3   Platform                    103 non-null    object
#  4   Daily_Usage_Time (minutes)  103 non-null    int64
#  5   Posts_Per_Day               103 non-null    int64
#  6   Likes_Received_Per_Day      103 non-null    int64
#  7   Comments_Received_Per_Day   103 non-null    int64
#  8   Messages_Sent_Per_Day       103 non-null    int64
#  9   Dominant_Emotion            103 non-null    object
# dtypes: int64(6), object(4)
# memory usage: 8.2+ KB

# %%
data.describe()
# Out:
#           User_ID  Daily_Usage_Time (minutes)  Posts_Per_Day  \
# count  103.000000                  103.000000     103.000000
# mean   521.262136                   88.009709       2.864078
# std    288.949991                   33.979087       1.732326
# min     16.000000                   40.000000       1.000000
# 25%    275.000000                   60.000000       1.000000
# 50%    526.000000                   75.000000       2.000000
# 75%    776.000000                  105.000000       4.000000
# max    997.000000                  200.000000       8.000000
#
#        Likes_Received_Per_Day  Comments_Received_Per_Day  \
# count              103.000000                 103.000000
# mean                33.456311                  13.766990
# std                 23.031426                   8.107372
# min                  5.000000                   2.000000
# 25%                 15.000000                   7.000000
# 50%                 27.000000                  12.000000
# ...

# %%
data.size
# Out:
# 1030

# %%
data.shape
# Out:
# (103, 10)

# %%
data.columns
# Out:
# Index(['User_ID', 'Age', 'Gender', 'Platform', 'Daily_Usage_Time (minutes)',
#        'Posts_Per_Day', 'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# User_ID                       0
# Age                           0
# Gender                        0
# Platform                      0
# Daily_Usage_Time (minutes)    0
# Posts_Per_Day                 0
# Likes_Received_Per_Day        0
# Comments_Received_Per_Day     0
# Messages_Sent_Per_Day         0
# Dominant_Emotion              0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 4

# %%
data.drop_duplicates(inplace = True)

# %%
data.shape
# Out:
# (99, 10)

# %%
data.Gender.unique()
# Out:
# array(['Female', 'Non-binary', 'Male', '27', 'Marie'], dtype=object)

# %%
data.Age.unique()
# Out:
# array(['27', '21', '28', '25', '24', '33', '32', '23', '35', '31', '34',
#        '29', '22', '26', '30', 'Male'], dtype=object)

# %%
data.Platform.unique()
# Out:
# array(['Snapchat', 'Telegram', 'Facebook', 'Instagram', 'LinkedIn',
#        'Twitter', 'Whatsapp'], dtype=object)

# %%
data.Dominant_Emotion.unique()
# Out:
# array(['Neutral', 'Anxiety', 'Happiness', 'Boredom', 'Sadness', 'Anger'],
#       dtype=object)

# %% [markdown]
# ### interchanging the values

# %%
data.Age.replace({'Male':27},inplace = True)

# %%
data.Gender.replace({'27':'Male'},inplace = True)

# %% [markdown]
# ### Replacing 'Marie' with mode()

# %%
data.Gender.mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
data.Gender.replace({'Marie':'Male'},inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 0 to 101
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     99 non-null     int64
#  1   Age                         99 non-null     object
#  2   Gender                      99 non-null     object
#  3   Platform                    99 non-null     object
#  4   Daily_Usage_Time (minutes)  99 non-null     int64
#  5   Posts_Per_Day               99 non-null     int64
#  6   Likes_Received_Per_Day      99 non-null     int64
#  7   Comments_Received_Per_Day   99 non-null     int64
#  8   Messages_Sent_Per_Day       99 non-null     int64
#  9   Dominant_Emotion            99 non-null     object
# dtypes: int64(6), object(4)
# memory usage: 8.5+ KB

# %%
data['Age'] = data['Age'].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 0 to 101
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     99 non-null     int64
#  1   Age                         99 non-null     int32
#  2   Gender                      99 non-null     object
#  3   Platform                    99 non-null     object
#  4   Daily_Usage_Time (minutes)  99 non-null     int64
#  5   Posts_Per_Day               99 non-null     int64
#  6   Likes_Received_Per_Day      99 non-null     int64
#  7   Comments_Received_Per_Day   99 non-null     int64
#  8   Messages_Sent_Per_Day       99 non-null     int64
#  9   Dominant_Emotion            99 non-null     object
# dtypes: int32(1), int64(6), object(3)
# memory usage: 8.1+ KB

# %%
Age_wise_usage = pd.crosstab(data.Age,data.Platform,margins = True)

# %%
Age_wise_usage
# Out:
# Platform  Facebook  Instagram  LinkedIn  Snapchat  Telegram  Twitter  \
# Age
# 21               3          0         0         1         0        1
# 22               2          0         0         1         0        1
# 23               2          0         3         0         0        3
# 24               1          0         1         1         2        1
# 25               0          4         0         0         2        0
# 26               6          0         0         0         0        2
# 27               2          1         2         3         2        2
# 28               0          3         1         3         1        3
# 29               4          0         1         3         0        1
# 30               0          1         0         0         0        2
# 31               2          1         2         0         4        0
# 32               0          5         0         0         0        0
# ...

# %% [markdown]
# ## Univariate Graphs

# %% [markdown]
# ### Histogram

# %%
plt.figure(figsize =(6,4))
sns.histplot(data = data, x='Age')
plt.show()

# %% [markdown]
# ### Box plot

# %%
plt.figure(figsize =(10,6))
sns.boxplot(data = data,  y = 'Daily_Usage_Time (minutes)')
plt.show()

# %% [markdown]
# ### KDE Plot (Kernal Density Estimation)

# %%
sns.kdeplot(x=data.Age)
plt.show()

# %%
sns.kdeplot(x=data.Posts_Per_Day )
plt.show()

# %% [markdown]
# ### Violin plot

# %%
sns.violinplot(data = data, y='Posts_Per_Day')
plt.show()

# %%
sns.violinplot(data = data, y='Likes_Received_Per_Day')
plt.show()

# %%
sns.violinplot(data = data, y='Comments_Received_Per_Day')
plt.show()

# %%
sns.violinplot(data = data, y='Messages_Sent_Per_Day')
plt.show()

# %%
data.drop(columns = 'User_ID',inplace = True)

# %%
plt.figure(figsize = (18,6))
plt.xticks(rotation = 75)
sns.boxplot(data = data)
plt.show()

# %% [markdown]
# ## Bivariate Graph

# %% [markdown]
# ### Horizontal Bar chart

# %%
plt.figure(figsize = (6,5))
plt.xticks(rotation = 90)
sns.barplot(data = data, x='Age', y='Gender')
plt.show()

# %%
data.Gender.unique()
# Out:
# array(['Female', 'Non-binary', 'Male'], dtype=object)

# %%
plt.figure(figsize = (6,5))
plt.xticks(rotation = 90)
sns.barplot(data = data, x='Daily_Usage_Time (minutes)', y='Gender')
plt.show()

# %% [markdown]
# ### Vertical Bar chart

# %%
plt.figure(figsize = (6,5))
plt.xticks(rotation = 90)
sns.barplot(data = data, x='Platform', y='Age')
plt.show()

# %%
plt.figure(figsize = (6,5))
plt.xticks(rotation = 90)
sns.barplot(data = data, x='Platform', y='Daily_Usage_Time (minutes)')
plt.show()

# %% [markdown]
# ### Line Chart

# %%
plt.figure(figsize = (8,5))
plt.xlabel('Gender')
plt.ylabel('Daily_Usage_Time (minutes)')
plt.title('usage_time')
sns.lineplot(data = data,x='Gender',y='Daily_Usage_Time (minutes)')
plt.show()

# %% [markdown]
# ### Count Plot

# %%
plt.figure(figsize = (6,6))
plt.xticks(rotation = 90)
sns.countplot(data = data, x ='Gender')
plt.show()

# %% [markdown]
# ### Area chart

# %%
plt.figure(figsize =(15,5))
plt.xticks(rotation = 90)
plt.stackplot(data.Gender,data.Posts_Per_Day,data.Likes_Received_Per_Day,data.Comments_Received_Per_Day,data.Messages_Sent_Per_Day)
plt.show()

# %%
data.head()
# Out:
#    Age      Gender  Platform  Daily_Usage_Time (minutes)  Posts_Per_Day  \
# 0   27      Female  Snapchat                         120              4
# 1   21  Non-binary  Snapchat                          60              1
# 2   28  Non-binary  Snapchat                         115              3
# 3   27        Male  Telegram                         105              3
# 4   21  Non-binary  Facebook                          55              3
#
#    Likes_Received_Per_Day  Comments_Received_Per_Day  Messages_Sent_Per_Day  \
# 0                      40                         18                     22
# 1                      18                          7                     12
# 2                      38                         18                     27
# 3                      48                         20                     28
# 4                      17                          7                     12
#
#   Dominant_Emotion
# 0          Neutral
# 1          Neutral
# ...

# %% [markdown]
# ### Scatter plot

# %%
sns.scatterplot(data = data, x='Gender',y='Daily_Usage_Time (minutes)',hue='Platform')
plt.show()

# %%
sns.scatterplot(data = data, x='Gender',y='Daily_Usage_Time (minutes)',hue='Dominant_Emotion')
plt.show()

# %%
sns.scatterplot(data = data, x='Gender',y='Platform',hue='Dominant_Emotion')
plt.show()

# %%
data.Gender.value_counts()
# Out:
# Gender
# Male          46
# Non-binary    28
# Female        25
# Name: count, dtype: int64

# %%
data.Dominant_Emotion.value_counts()
# Out:
# Dominant_Emotion
# Neutral      26
# Anxiety      21
# Boredom      15
# Happiness    14
# Sadness      14
# Anger         9
# Name: count, dtype: int64

# %%
data_numerical = data.select_dtypes(int)

# %%
data_numerical
# Out:
#      Age  Daily_Usage_Time (minutes)  Posts_Per_Day  Likes_Received_Per_Day  \
# 0     27                         120              4                      40
# 1     21                          60              1                      18
# 2     28                         115              3                      38
# 3     27                         105              3                      48
# 4     21                          55              3                      17
# ..   ...                         ...            ...                     ...
# 97    27                          90              3                      40
# 98    22                          70              1                      20
# 99    33                          85              4                      35
# 100   24                         110              6                      35
# 101   24                          75              3                      37
#
#      Comments_Received_Per_Day  Messages_Sent_Per_Day
# ...

# %%
data_numerical.corr()
# Out:
#                                  Age  Daily_Usage_Time (minutes)  \
# Age                         1.000000                    0.116716
# Daily_Usage_Time (minutes)  0.116716                    1.000000
# Posts_Per_Day               0.033061                    0.876904
# Likes_Received_Per_Day      0.114553                    0.929893
# Comments_Received_Per_Day   0.109339                    0.892758
# Messages_Sent_Per_Day       0.097289                    0.876577
#
#                             Posts_Per_Day  Likes_Received_Per_Day  \
# Age                              0.033061                0.114553
# Daily_Usage_Time (minutes)       0.876904                0.929893
# Posts_Per_Day                    1.000000                0.924489
# Likes_Received_Per_Day           0.924489                1.000000
# Comments_Received_Per_Day        0.935499                0.941839
# Messages_Sent_Per_Day            0.864655                0.898108
#
# ...

# %%
sns.heatmap(data_numerical.corr()[["Daily_Usage_Time (minutes)"]].sort_values(by="Daily_Usage_Time (minutes)",ascending=False),vmin=-1,vmax=1,annot=True,cmap="Greens")
plt.show()

# %%
data_categorical = data.select_dtypes(object)

# %%
data_categorical
# Out:
#          Gender  Platform Dominant_Emotion
# 0        Female  Snapchat          Neutral
# 1    Non-binary  Snapchat          Neutral
# 2    Non-binary  Snapchat          Anxiety
# 3          Male  Telegram          Anxiety
# 4    Non-binary  Facebook          Neutral
# ..          ...       ...              ...
# 97         Male   Twitter          Sadness
# 98         Male   Twitter          Neutral
# 99         Male  LinkedIn          Boredom
# 100  Non-binary  Facebook          Sadness
# 101        Male  Telegram          Neutral
#
# [99 rows x 3 columns]

# %% [markdown]
# ### regplot

# %%
sns.regplot(data=data,x='Age',y='Daily_Usage_Time (minutes)')
plt.show()

# %% [markdown]
# ### relplot

# %%
sns.relplot(data=data,x='Age',y='Daily_Usage_Time (minutes)',size='Platform')
plt.show()

# %%
sns.relplot(data=data,x='Gender',y='Daily_Usage_Time (minutes)',size='Dominant_Emotion')
plt.show()

# %%
data.head()
# Out:
#    Age      Gender  Platform  Daily_Usage_Time (minutes)  Posts_Per_Day  \
# 0   27      Female  Snapchat                         120              4
# 1   21  Non-binary  Snapchat                          60              1
# 2   28  Non-binary  Snapchat                         115              3
# 3   27        Male  Telegram                         105              3
# 4   21  Non-binary  Facebook                          55              3
#
#    Likes_Received_Per_Day  Comments_Received_Per_Day  Messages_Sent_Per_Day  \
# 0                      40                         18                     22
# 1                      18                          7                     12
# 2                      38                         18                     27
# 3                      48                         20                     28
# 4                      17                          7                     12
#
#   Dominant_Emotion
# 0          Neutral
# 1          Neutral
# ...

# %% [markdown]
# ### catplot

# %%
plt.figure(figsize=(5,20))
sns.catplot(data=data,x='Platform',y='Daily_Usage_Time (minutes)')
plt.show()

# %% [markdown]
# ### Boxen plot

# %%
sns.boxenplot(data=data,y='Posts_Per_Day')
plt.show()

# %% [markdown]
# ### Joint plot

# %%
sns.jointplot(data=data,x='Age',y='Posts_Per_Day',kind='hex')
plt.show()

# %% [markdown]
# ### swarm plot

# %%
sns.swarmplot(data=data,x='Dominant_Emotion',y='Age')
plt.show()

# %% [markdown]
# ### pair plot

# %%
sns.pairplot(data=data)
plt.show()

# %%
sns.countplot(data=data,x='Gender')
plt.show()

# %%
sns.countplot(data=data,x='Age')
plt.show()

# %%
sns.countplot(data=data,x='Dominant_Emotion')
plt.show()

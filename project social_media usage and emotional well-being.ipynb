# %% [markdown]
# # SOCIAL_MEDIA USAGE AND EMOTIONAL WELL_BEING

# %% [markdown]
# ![social-media.jpg](attachment:196f7fdb-abbf-4686-b9af-e45eec2528b8.jpg)

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# Social media is a digital technology that allows sharing of ideas and information including text and visuals, through virtual networks and communications. However, multiple studies have found a strong link between heavy social media use and an increased risk for anxiety,anger and sadness.
# This analysis explores a dataset that captures social media usage and users dominant emotional states. The goal of this Project is to understand the relationship between social media usage patterns and emotional well-being.

# %% [markdown]
# # ABOUT THE DATASET

# %% [markdown]
# This unique dataset was meticulously researched and prepared by AI inventor Emirhan Bulut. It captures valuable information on social media usage and the dominant emotional state of users based on their activities. The dataset is ideal for exploring the relationship between social media usage patterns and emotional well-being.
# The dataset contain 10 columns and 103 rows.
#
# Feature description:
#
# <li>User_ID:   Unique identifier for the user.
# <li>Age:   Age of the user.
# <li>Gender:   Gender of the user (Female, Male, Non-binary).
# <li>Platform:   Social media platform used (e.g., Instagram, Twitter, Facebook, LinkedIn, Snapchat, Whatsapp, Telegram).
# <li>Daily_Usage_Time (minutes):   Daily time spent on the platform in minutes.
# <li>Posts_Per_Day:   Number of posts made per day.
# <li>Likes_Received_Per_Day:   Number of likes received per day.
# <li>Comments_Received_Per_Day:   Number of comments received per day.
# <li>Messages_Sent_Per_Day:   Number of messages sent per day.
# <li>Dominant_Emotion:   User's dominant emotional state during the day (e.g., Happiness, Sadness, Anger, Anxiety, Boredom, Neutral).

# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## LOADING THE DATASET

# %%
data = pd.read_csv('./social_media usage and emotional well-being.csv')
data
# Out:
#      User_ID Age      Gender  Platform  Daily_Usage_Time (minutes)  \
# 0        500  27      Female  Snapchat                         120
# 1        488  21  Non-binary  Snapchat                          60
# 2        776  28  Non-binary  Snapchat                         115
# 3        869  27        Male  Telegram                         105
# 4        573  21  Non-binary  Facebook                          55
# ..       ...  ..         ...       ...                         ...
# 98       184  22        Male   Twitter                          70
# 99       896  33        Male  LinkedIn                          85
# 100      708  24  Non-binary  Facebook                         110
# 101      993  24        Male  Telegram                          75
# 102       60  27        Male  Facebook                          60
#
#      Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0                4                      40                         18
# ...

# %%
data.head()  # loading first few rows of dataset
# Out:
#    User_ID Age      Gender  Platform  Daily_Usage_Time (minutes)  \
# 0      500  27      Female  Snapchat                         120
# 1      488  21  Non-binary  Snapchat                          60
# 2      776  28  Non-binary  Snapchat                         115
# 3      869  27        Male  Telegram                         105
# 4      573  21  Non-binary  Facebook                          55
#
#    Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0              4                      40                         18
# 1              1                      18                          7
# 2              3                      38                         18
# 3              3                      48                         20
# 4              3                      17                          7
#
#    Messages_Sent_Per_Day Dominant_Emotion
# 0                     22          Neutral
# 1                     12          Neutral
# ...

# %%
data.tail() # loading last few rows of dataset
# Out:
#      User_ID Age      Gender  Platform  Daily_Usage_Time (minutes)  \
# 98       184  22        Male   Twitter                          70
# 99       896  33        Male  LinkedIn                          85
# 100      708  24  Non-binary  Facebook                         110
# 101      993  24        Male  Telegram                          75
# 102       60  27        Male  Facebook                          60
#
#      Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 98               1                      20                          5
# 99               4                      35                         18
# 100              6                      35                         23
# 101              3                      37                         16
# 102              1                      10                          4
#
#      Messages_Sent_Per_Day Dominant_Emotion
# 98                      22          Neutral
# 99                      18          Boredom
# ...

# %% [markdown]
# ### Information related to data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     103 non-null    int64
#  1   Age                         103 non-null    object
#  2   Gender                      103 non-null    object
#  3   Platform                    103 non-null    object
#  4   Daily_Usage_Time (minutes)  103 non-null    int64
#  5   Posts_Per_Day               103 non-null    int64
#  6   Likes_Received_Per_Day      103 non-null    int64
#  7   Comments_Received_Per_Day   103 non-null    int64
#  8   Messages_Sent_Per_Day       103 non-null    int64
#  9   Dominant_Emotion            103 non-null    object
# dtypes: int64(6), object(4)
# memory usage: 8.2+ KB

# %% [markdown]
# The info() function provides information about the dataset including the number of rows and columns ,data type of each column,
# non-null value count and memory usage.

# %% [markdown]
# ## Measures of Central_tendency and Dispersion

# %%
data.describe()
# Out:
#           User_ID  Daily_Usage_Time (minutes)  Posts_Per_Day  \
# count  103.000000                  103.000000     103.000000
# mean   521.262136                   88.009709       2.864078
# std    288.949991                   33.979087       1.732326
# min     16.000000                   40.000000       1.000000
# 25%    275.000000                   60.000000       1.000000
# 50%    526.000000                   75.000000       2.000000
# 75%    776.000000                  105.000000       4.000000
# max    997.000000                  200.000000       8.000000
#
#        Likes_Received_Per_Day  Comments_Received_Per_Day  \
# count              103.000000                 103.000000
# mean                33.456311                  13.766990
# std                 23.031426                   8.107372
# min                  5.000000                   2.000000
# 25%                 15.000000                   7.000000
# 50%                 27.000000                  12.000000
# ...

# %% [markdown]
# The describe() function gives the describtion (count,mean,standard deviation,minimum and maximum values)of each numerical column
# in a dataset.

# %% [markdown]
# ### Display column names

# %%
data.columns
# Out:
# Index(['User_ID', 'Age', 'Gender', 'Platform', 'Daily_Usage_Time (minutes)',
#        'Posts_Per_Day', 'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion'],
#       dtype='object')

# %% [markdown]
# ### size and shape of a dataset

# %%
data.size
# Out:
# 1030

# %%
data.shape
# Out:
# (103, 10)

# %% [markdown]
# The dataset has 103 rows and 10 columns ,and its total size is 1030.

# %% [markdown]
# ### Finding null value count

# %%
data.isnull().sum()
# Out:
# User_ID                       0
# Age                           0
# Gender                        0
# Platform                      0
# Daily_Usage_Time (minutes)    0
# Posts_Per_Day                 0
# Likes_Received_Per_Day        0
# Comments_Received_Per_Day     0
# Messages_Sent_Per_Day         0
# Dominant_Emotion              0
# dtype: int64

# %% [markdown]
# The data set don't have any null value

# %% [markdown]
# ### Finding duplicate values

# %%
data.duplicated().sum()
# Out:
# 4

# %% [markdown]
# ### Removing duplicate values

# %%
data.drop_duplicates(inplace = True)

# %%
data.size
# Out:
# 990

# %%
data.shape
# Out:
# (99, 10)

# %% [markdown]
# We have removed the 4 duplicate values. Now the dataset has 99 rows and 10 columns.

# %% [markdown]
# ## Display Datatypes

# %%
data.dtypes
# Out:
# User_ID                        int64
# Age                           object
# Gender                        object
# Platform                      object
# Daily_Usage_Time (minutes)     int64
# Posts_Per_Day                  int64
# Likes_Received_Per_Day         int64
# Comments_Received_Per_Day      int64
# Messages_Sent_Per_Day          int64
# Dominant_Emotion              object
# dtype: object

# %% [markdown]
# The dtypes() function shows the data type of each column. It shows the datatype of column 'Age' is 'object' instead of 'int'.

# %% [markdown]
# ## Dropping Irrelevant features

# %%
data.drop(columns = 'User_ID',inplace = True) # removing the unwanted column user_id using drop function.

# %% [markdown]
# ### unique values

# %%
data.Gender.unique()
# Out:
# array(['Female', 'Non-binary', 'Male', '27', 'Marie'], dtype=object)

# %%
data.Age.unique()
# Out:
# array(['27', '21', '28', '25', '24', '33', '32', '23', '35', '31', '34',
#        '29', '22', '26', '30', 'Male'], dtype=object)

# %%
data.Platform.unique()
# Out:
# array(['Snapchat', 'Telegram', 'Facebook', 'Instagram', 'LinkedIn',
#        'Twitter', 'Whatsapp'], dtype=object)

# %%
data.Dominant_Emotion.unique()
# Out:
# array(['Neutral', 'Anxiety', 'Happiness', 'Boredom', 'Sadness', 'Anger'],
#       dtype=object)

# %% [markdown]
# ### Interchanging the in-appropriate values

# %% [markdown]
# The Unique() function of Gender column gives the unique values such as 'Female','Male','Non-binary','27','Marie'. Clearly we can say the values '27' and 'Marie' are in-appropriate for the column.similarly, the Age column contain one object value 'Male' instead of an integer value. So we have to interchange the values and correct the datatype of each column.

# %%
data.Age.replace({'Male':27},inplace = True)

# %%
data.Gender.replace({'27':'Male'},inplace = True)

# %% [markdown]
# Replacing 'Marie' with Mode()   [ most occuring number]

# %%
data.Gender.mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
data.Gender.replace({'Marie':'Male'},inplace = True)

# %% [markdown]
# ### Changing the datatype of 'Age' column

# %%
data['Age'] = data['Age'].astype('int')

# %% [markdown]
# ## Display datatypes

# %%
data.dtypes
# Out:
# Age                            int32
# Gender                        object
# Platform                      object
# Daily_Usage_Time (minutes)     int64
# Posts_Per_Day                  int64
# Likes_Received_Per_Day         int64
# Comments_Received_Per_Day      int64
# Messages_Sent_Per_Day          int64
# Dominant_Emotion              object
# dtype: object

# %% [markdown]
# <li> 3 columns are of the object data type
# <li> 6 columns are of the int data type, representing integer values.

# %% [markdown]
# ### Age wise total count

# %%
Age_wise_usage = pd.crosstab(data.Age,data.Platform,margins = True)

# %%
Age_wise_usage
# Out:
# Platform  Facebook  Instagram  LinkedIn  Snapchat  Telegram  Twitter  \
# Age
# 21               3          0         0         1         0        1
# 22               2          0         0         1         0        1
# 23               2          0         3         0         0        3
# 24               1          0         1         1         2        1
# 25               0          4         0         0         2        0
# 26               6          0         0         0         0        2
# 27               2          1         2         3         2        2
# 28               0          3         1         3         1        3
# 29               4          0         1         3         0        1
# 30               0          1         0         0         0        2
# 31               2          1         2         0         4        0
# 32               0          5         0         0         0        0
# ...

# %% [markdown]
# ### Gender wise total count

# %%
Gender_wise_usage = pd.crosstab(data.Gender,data.Platform,margins = True)

# %%
Gender_wise_usage
# Out:
# Platform    Facebook  Instagram  LinkedIn  Snapchat  Telegram  Twitter  \
# Gender
# Female             2          9         1         5         0        6
# Male               7          7         8         0        10       12
# Non-binary        13          0         6         7         1        1
# All               22         16        15        12        11       19
#
# Platform    Whatsapp  All
# Gender
# Female             2   25
# Male               2   46
# Non-binary         0   28
# All                4   99

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Distribution of Age

# %%
plt.figure(figsize =(8,6))
sns.histplot(data = data, x='Age', kde = True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The Histogram plot of Age Distribution shows the Age group between 28 to 30 are the most common social media users. After 30, its going down.

# %%
sns.countplot(data=data,x='Age')
plt.show()

# %% [markdown]
# ### Gender Distribution

# %%
plt.figure(figsize =(5,6))
sns.countplot(data = data, x='Gender')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The count plot of Gender Distribution shows the Gender Male are the common social media users followed by Non-binary and Females.

# %% [markdown]
# ### Social media Platform distribution

# %%
plt.figure(figsize =(10,6))
sns.countplot(data = data, x='Platform')
plt.title('Platform Distribution')
plt.xlabel('Platform')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Facebook is the most commonly used platform, followed by Twitter and Instagram

# %% [markdown]
# ### Distribution of Daily usage time

# %%
plt.figure(figsize =(8,6))
sns.boxplot(data = data, y='Daily_Usage_Time (minutes)')
plt.title('Distribution of Daily usage time')
plt.ylabel('Daily_Usage_Time (minutes)')
plt.xlabel('Frequency')
plt.show()

# %% [markdown]
# The Box plot of Daily usage time showing that the average social media usage time is in between 60 to 100 minutes. very less people are using more than 160 minutes(the outlayers).

# %% [markdown]
# ### Distribution of Dominant Emotion

# %%
data.Dominant_Emotion.value_counts()
# Out:
# Dominant_Emotion
# Neutral      26
# Anxiety      21
# Boredom      15
# Happiness    14
# Sadness      14
# Anger         9
# Name: count, dtype: int64

# %%
plt.figure(figsize =(6,8))
sns.countplot(data = data, x='Dominant_Emotion')
plt.title('Distribution of Dominant_Emotion')
plt.xlabel('Dominant_Emotion')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The distribution of dominant_emotion showing that more people are in Neutral stage, followed by Anxiety,Boredom,Happiness,Sadness and Anger.

# %% [markdown]
# ### Gender wise Daily usage

# %%
plt.figure(figsize =(6,8))
sns.barplot(data=data,x='Gender',y='Daily_Usage_Time (minutes)')
plt.show()

# %% [markdown]
# Female spent more time with social media followed by Male and Non-binary people.

# %% [markdown]
# ### Comparison

# %%
plt.figure(figsize =(6,8))
sns.barplot(data=data,x='Gender',y='Daily_Usage_Time (minutes)',hue='Dominant_Emotion')
plt.show()

# %% [markdown]
# ### Comparison of Platform and Emotion

# %%
sns.countplot(data=data,x='Platform',hue='Dominant_Emotion')
plt.show()

# %% [markdown]
# This comparison showing Instagram users appear more Happiness compared to other social media platform, while the Telegram,Facebook, Linkedin, and whatsapp users not getting any happiness. They felt more anger,sadness ,boredom and anxiety compared to instagram users.

# %% [markdown]
# ### Comparison of Gender and Emotion

# %%
sns.countplot(data=data,x='Gender',hue='Dominant_Emotion')
plt.show()

# %% [markdown]
# Most of the male users get bored while using social media, while female users felt happiness

# %% [markdown]
# ### Gender and commonly used platform

# %%
sns.countplot(data=data,x='Gender',hue='Platform')
plt.show()

# %% [markdown]
# Instagram is the favourite social media platform for Females, while Facebook and Twitter are favourites for Non-binary and Male respectively.

# %% [markdown]
# ### How social media usage time affect Dominant_Emotion

# %%
sns.barplot(data=data,x='Daily_Usage_Time (minutes)',y='Dominant_Emotion')
plt.show()

# %% [markdown]
# The barplot shows that the social media usage time gives more happiness, followed by Anxiety and Anger.And the less usage feel boredom.

# %% [markdown]
# ### Scatterplot of Age, Daily usage time and Platform

# %%
sns.scatterplot(data = data, x='Age',y='Daily_Usage_Time (minutes)',hue='Platform')
plt.show()

# %% [markdown]
# This scatterplot shows that Instagram is the most used social media platform

# %% [markdown]
# ### Scatter plot of Age, Daily usage time and Dominant emotion

# %%
sns.scatterplot(data = data, x='Age',y='Daily_Usage_Time (minutes)',hue='Dominant_Emotion')
plt.show()

# %% [markdown]
# This scatterplot showing that the over use of social media lead to Anxiety. The daily usage time between 140 to below 180 minutes( less than 3 hours) gives happiness.

# %% [markdown]
# ### Social media activity and Dominant emotion

# %%
sns.scatterplot(data = data, x='Posts_Per_Day',y='Messages_Sent_Per_Day',hue='Dominant_Emotion')
plt.show()

# %% [markdown]
# This scatter plot showing that people who do 5 to 7 post per day and sending average of 30 to 40 messages per day, felt happiness .

# %%
sns.scatterplot(data = data, x='Likes_Received_Per_Day',y='Comments_Received_Per_Day',hue='Dominant_Emotion')
plt.show()

# %% [markdown]
# People who receiving average likes between 60 to 100 and 20 to 30 comments felt happiness

# %% [markdown]
# ### Heat map

# %%
data_numerical = data.select_dtypes(int)

# %%
data_numerical
# Out:
#      Age  Daily_Usage_Time (minutes)  Posts_Per_Day  Likes_Received_Per_Day  \
# 0     27                         120              4                      40
# 1     21                          60              1                      18
# 2     28                         115              3                      38
# 3     27                         105              3                      48
# 4     21                          55              3                      17
# ..   ...                         ...            ...                     ...
# 97    27                          90              3                      40
# 98    22                          70              1                      20
# 99    33                          85              4                      35
# 100   24                         110              6                      35
# 101   24                          75              3                      37
#
#      Comments_Received_Per_Day  Messages_Sent_Per_Day
# ...

# %%
data_numerical.corr()
# Out:
#                                  Age  Daily_Usage_Time (minutes)  \
# Age                         1.000000                    0.116716
# Daily_Usage_Time (minutes)  0.116716                    1.000000
# Posts_Per_Day               0.033061                    0.876904
# Likes_Received_Per_Day      0.114553                    0.929893
# Comments_Received_Per_Day   0.109339                    0.892758
# Messages_Sent_Per_Day       0.097289                    0.876577
#
#                             Posts_Per_Day  Likes_Received_Per_Day  \
# Age                              0.033061                0.114553
# Daily_Usage_Time (minutes)       0.876904                0.929893
# Posts_Per_Day                    1.000000                0.924489
# Likes_Received_Per_Day           0.924489                1.000000
# Comments_Received_Per_Day        0.935499                0.941839
# Messages_Sent_Per_Day            0.864655                0.898108
#
# ...

# %%
sns.heatmap(data_numerical.corr()[["Daily_Usage_Time (minutes)"]].sort_values(by="Daily_Usage_Time (minutes)",ascending=False),vmin=-1,vmax=1,annot=True,cmap="Greens")
plt.show()

# %% [markdown]
# ### Box plot

# %%
plt.figure(figsize = (18,6))
plt.xticks(rotation = 75)
sns.boxplot(data = data)
plt.show()

# %% [markdown]
# ### How age affect Dominant emotion

# %%
plt.figure(figsize = (18,6))
sns.boxplot(data=data, x='Dominant_Emotion', y='Age')
plt.show()

# %% [markdown]
# Age 30 above feels bore while using social media

# %% [markdown]
# ## Dominant emotion and social media activity

# %%
plt.figure(figsize = (18,6))
sns.boxplot(data=data, x='Dominant_Emotion', y='Daily_Usage_Time (minutes)')
plt.show()

# %% [markdown]
# The daily usage time between 140 to 180 gives happiness.

# %%
plt.figure(figsize = (18,6))
sns.boxplot(data=data, x='Dominant_Emotion', y='Posts_Per_Day')
plt.show()

# %% [markdown]
# Most poeple do less than 4 post per day, they appear emotionally neutral. most People who post 5-6 posts get happiness and more than 8 post per day leads to anxiety.

# %%
plt.figure(figsize = (18,6))
sns.boxplot(data=data, x='Dominant_Emotion', y='Likes_Received_Per_Day')
plt.show()

# %% [markdown]
# Most people who gets less than 60 likes per day feels anger and less than 20 likes feels boredom. Getting  more than 70 like per day leads to happiess.

# %%
plt.figure(figsize = (18,6))
sns.boxplot(data=data, x='Dominant_Emotion', y='Comments_Received_Per_Day')
plt.show()

# %% [markdown]
# People who getting 20 to 30 comments per day feel happy.

# %%
plt.figure(figsize = (18,6))
sns.boxplot(data=data, x='Dominant_Emotion', y='Messages_Sent_Per_Day')
plt.show()

# %% [markdown]
# The happiest people sent average of 25 to 30 messages per day, and the common category is neutral, they sent around 15 to 20 messages per day.

# %% [markdown]
# ## Gender and social media activity

# %%
plt.figure(figsize = (18,6))
sns.boxplot(data=data, x='Gender', y='Posts_Per_Day')
plt.show()

# %%
plt.figure(figsize = (18,6))
sns.boxplot(data=data, x='Gender', y='Likes_Received_Per_Day')
plt.show()

# %%
plt.figure(figsize = (18,6))
sns.boxplot(data=data, x='Gender', y='Comments_Received_Per_Day')
plt.show()

# %%
plt.figure(figsize = (18,6))
sns.boxplot(data=data, x='Gender', y='Messages_Sent_Per_Day')
plt.show()

# %% [markdown]
# As we shown above, the Gender and social media activity box plot shows, the common social media users are 'Male', however 'Female' spend more time with social media and they are active in social media. They are getting more comments and likes compared to 'Male'. They are doing 3 to 5 post per day and sending average of 20 to 30 messages per day.

# %% [markdown]
# ## Conclusion Points

# %% [markdown]
# <li>Gender 'Male' are the most common social media users followed by 'non-binary' and 'female'.
# <li>Gender 'Female' spend more time with social media compared to 'Male'.
# <li>Gender 'Female' are more active in social media.
# <li>Age group between 28 to 30 are the common social media users, and above 30 age shows continuous decrease usage of social media.
# <li>Facebook is the most commonly used social media platform followed by Twitter and Instagram.
# <li>Whatsapp is the less used social media platform.
# <li>The average daily usage time of social media is 1 to 2 hours per day.
# <li>Instagram users felt emotionally happy compared to other social media platform.
# <li>Gender 'Female' spent more time with Instagram.
# <li>People who spent more than 3 hours with social media felt Anxiety.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# From the above analysis we can conclude that the average use of social media gives happiness ,while the over use of (more than 3 hours) social media leads to Anxiety.
